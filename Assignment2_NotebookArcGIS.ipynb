# %% [markdown]
# ## Python Lab Assignment 2- Sarah Collingsworth
# ### Student ID 220009965
# ### https://github.com/secworth35/Assignment_2_SarahCollingsworth

# %% [markdown]
# ## Part 1

# %%
#Task 1
x = 4
if x/3:
    print(str(x) + " is divisible by 3")
else:
    print(str(x) + " is not divisible by 3")

x = 0
if x/3:
    print(str(x) + " is divisible by 3")
else:
    print(str(x) + " is not divisible by 3")
# Out:
# 4 is divisible by 3
# 0 is not divisible by 3

# %%
#Task 2
fruits = ["apple", "orange", "pear", "kiwi", "strawberry"]
x = "apple"
if x in fruits:
    print(str(x) + " is acceptable")
else: 
    print(str(x) + " is not acceptable")

x = "blueberry"
if x in fruits:
    print(str(x) + " is acceptable")
else: 
    print(str(x) + " is not acceptable")
# Out:
# apple is acceptable
# blueberry is not acceptable

# %%
#Task 3
lst1 = [1, 4]
lst2= [3, 2]
import math as m
a = (sin*sin)((lst2[1])lst2 - (lst[1])lst1/2) + cos (lst1[1])(lst1) * cos (lst2[1]lst2 * (sin*sin)((lst2[0])lst2 - (lst1[0])lst1/2)
c = 2 * atan2( √a, √(1−a) )
d = R ⋅ c

# %% [markdown]
# ## Part 2

# %%
txt1 = "H:/GG3209/Lab Assignment 2/Assignment 2 Data/Assignment 2 Data/portland_park_trees.csv"

# %%
dataset = '/arcgis/home/portland_park_trees.csv'

# %%
import numpy as np
import pandas as pd

trees_df = pd.read_csv('/arcgis/home/portland_park_trees.csv', index_col=0)

# %%
trees_df['Genus']
# Out:
# fid
# 1        Pseudotsuga
# 2        Pseudotsuga
# 3          Crataegus
# 4            Quercus
# 5        Pseudotsuga
#             ...
# 25530        Quercus
# 25531    Pseudotsuga
# 25532    Metasequoia
# 25533          Picea
# 25534         Cornus
# Name: Genus, Length: 25534, dtype: object

# %%
trees_df.query("Genus == 'Quercus'")
# Out:
#        OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# fid
# 4           429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 12          437  2017/05/09    QURU  14.9      Fair        48.0        33.0
# 55          480  2017/05/19    QUPA  37.1      Fair        85.0        70.0
# 87          512  2017/05/22    QUFR  22.6      Good        65.0        48.0
# 97          522  2017/05/23    QUPA  29.8      Fair        65.0        77.0
# ...         ...         ...     ...   ...       ...         ...         ...
# 25461    719644  2019/10/09    QUPA  27.0      Fair        92.0        49.0
# 25462    719645  2019/10/09    QURU  34.4      Fair        66.0        68.0
# 25463    719646  2019/10/09    QURU  27.5      Fair        61.0        54.0
# 25488    721243  2019/10/09    QUSU   0.5      Good         9.0        10.0
# 25530    726046  2018/08/16    QURU  31.6      Fair        74.0        50.0
#
# ...

# %%
trees_df.query("Genus == 'Acer'")
# Out:
#        OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# fid
# 25          450  2017/05/15    ACGR   6.6      Fair        19.0        17.0
# 26          451  2017/05/15    ACGR   6.2      Fair        27.0        14.0
# 31          456  2017/05/15    ACPL  17.3      Fair        44.0        50.0
# 32          457  2017/05/17    ACDA   6.8      Fair        20.0        23.0
# 42          467  2017/05/17    ACSA  33.5      Poor       100.0        73.0
# ...         ...         ...     ...   ...       ...         ...         ...
# 25500    723643  2019/10/11    ACMA  84.5      Fair        69.0        62.0
# 25507    724045  2019/10/11    ACMA  63.0      Poor        46.0        56.0
# 25509    724047  2019/10/11    ACMA  35.0      Fair        57.0        52.0
# 25512    724444  2019/10/11    ACMA  38.4      Fair       102.0        42.0
# 25517    724843  2019/10/11    ACMA  19.0      Fair        64.0        45.0
#
# ...

# %% [markdown]
# #### Question 1- Quercus: 2,089, Acer: 3,586

# %%
trees_df.query("Genus == 'Quercus' & DBH > 50")
# Out:
#        OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# fid
# 1702      47875  2017/07/27    QURU  51.5      Fair       117.0       109.0
# 2020      58664  2017/08/02    QURU  58.5      Fair        93.0        95.0
# 2023      58667  2017/08/02    QURU  54.1      Good       104.0        80.0
# 2035      59062  2017/08/02    QURU  68.3      Good       107.0       109.0
# 2047      59459  2017/08/02    QURU  57.9      Fair        88.0       112.0
# ...         ...         ...     ...   ...       ...         ...         ...
# 19516    560378  2019/07/23    QURU  53.5      Fair       127.0        84.0
# 19524    560776  2019/07/23    QURU  59.4      Fair       131.0        80.0
# 21834    634789  2019/08/30    QURU  56.4      Good        90.0       111.0
# 24272    690856  2019/09/25    QUGA  69.9      Good       101.0        83.0
# 24462    695648  2019/09/27    QUGA  59.0      Fair        94.0        97.0
#
# ...

# %%
trees_df.query("Genus == 'Acer' & DBH > 50")
# Out:
#        OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# fid
# 128         953  2017/05/24    ACMA  50.5      Fair        90.0        83.0
# 153        1754  2017/05/24    ACMA  50.5      Fair        85.0        51.0
# 155        1756  2017/05/24    ACMA  52.7      Fair        94.0        73.0
# 163        2150  2017/05/24    ACMA  56.3      Fair        70.0        57.0
# 594       13044  2017/06/29    ACMA  50.9      Fair        90.0        59.0
# 596       13046  2017/06/29    ACMA  53.0      Poor        93.0        41.0
# 681       13131  2017/06/29    ACMA  52.7      Poor       100.0        80.0
# 815       20256  2017/07/07    ACSA  53.5      Fair        85.0        57.0
# 840       21067  2017/07/08    ACMA  53.5      Fair        78.0        82.0
# 1937      54675  2017/07/29    ACMA  51.6      Fair        80.0        57.0
# 3078      93457  2017/08/26    ACMA  52.7      Fair        86.0        80.0
# ...

# %% [markdown]
# #### Question 2- Quercus: 80, Acer: 44

# %%
trees_df.query("Genus == 'Acer'")['DBH'].mean()
# Out:
# 18.419085331846066

# %%
trees_df.query("Genus == 'Quercus'")['DBH'].mean()
# Out:
# 23.56823839157492

# %%
trees_df.query("Genus == 'Fraxinus'")['DBH'].mean()
# Out:
# 11.033609693877551

# %% [markdown]
# #### Question 3- Quercus has the highest mean DBH

# %%
trees_df.query("Genus == 'Acer'")['Species']
# Out:
# fid
# 25       ACGR
# 26       ACGR
# 31       ACPL
# 32       ACDA
# 42       ACSA
#          ...
# 25500    ACMA
# 25507    ACMA
# 25509    ACMA
# 25512    ACMA
# 25517    ACMA
# Name: Species, Length: 3586, dtype: object

# %%
trees_df.query("Genus == 'Acer'")['Species'].drop_duplicates()
# Out:
# fid
# 25         ACGR
# 31         ACPL
# 32         ACDA
# 42         ACSA
# 85         ACCA
# 88         ACRU
# 128        ACMA
# 321        ACFR
# 387       ACSA3
# 929        ACGI
# 1002       ACPA
# 1361     ACGDSC
# 1391       ACCI
# 1580       ACPS
# 5787       ACBU
# 6516       ACMO
# 7247       ACNE
# 18645      ACHD
# 19457      ACJA
# 22982      ACRF
# Name: Species, dtype: object

# %% [markdown]
# #### Question 4- There are 20 different species in the Acer genus

# %%
txt1 = "H:/GG3209/Lab Assignment 2/Assignment 2 Data/Assignment 2 Data/world_cities.csv"

# %%
dataset = '/arcgis/home/world_cities.csv'

# %%
cities_df = pd.read_csv('/arcgis/home/world_cities.csv', index_col=0)

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43645 entries, 'Abasan al-Jadidah to s-Hertogenbosch
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  43645 non-null  object
#  1   pop      43645 non-null  int64
#  2   lat      43645 non-null  float64
#  3   lon      43645 non-null  float64
#  4   capital  43645 non-null  int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Part 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
trees2_df = pd.read_csv('/arcgis/home/portland_park_trees2.csv', index_col=0)

# %%
trees2_df.head()
# Out:
#      OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  CrownWidth  \
# fid
# 1         426  2017/05/09    PSME  37.4      Fair       105.0        44.0
# 2         427  2017/05/09    PSME  32.5      Fair        94.0        49.0
# 3         428  2017/05/09    CRLA   9.7      Fair        23.0        28.0
# 4         429  2017/05/09    QURU  10.3      Poor        28.0        38.0
# 5         430  2017/05/09    PSME  33.2      Fair       102.0        43.0
#
#      CrownWid_1 CollectedB Notes  ...        Genus        Common_nam  \
# fid                               ...
# 1          57.0      staff   NaN  ...  Pseudotsuga       Douglas-fir
# 2          45.0      staff   NaN  ...  Pseudotsuga       Douglas-fir
# 3          27.0      staff   NaN  ...    Crataegus  Lavalle hawthorn
# 4          31.0      staff   NaN  ...      Quercus  northern red oak
# 5          44.0      staff   NaN  ...  Pseudotsuga       Douglas-fir
#
# ...

# %%
x = trees2_df['DBH'['Genus'] == 'Ulmus']

y = trees2_df['TreeHeight']

print(x)

# %%
sp1 = plt.scatter(x, y)

# %% [markdown]
# ### Part 4

# %%
txt4 = "H:/GG3209/Lab Assignment 2/Local_Nature_Reserves_-_Scotland/pub_lnatr.shp"

# %%
dataset = '/arcgis/home/pub_lnatr.shp'

# %%
import numpy as np
import pandas as pd

# %%
pip install geopandas fiona shapely pyproj rtree contextily folium matplotlib mapclassify

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#Task 1
gdf = gpd.read_file('/arcgis/home/pub_lnatr.shp')
#I don't know why the file won't read. I've also tried it with the file path from my H drive.
#I've followed the format of reading the file exactly as described in the lectures, so
#I don't know what to do to fix it, but I can't complete the rest of the section properly without
#being able to read the file.

# %%
#Task 2
gdf.head()
gdf.tail()

# %% [markdown]
# ### Part 5

# %%
pip install earthpy rasterio

# %%
txt5 = "H:/GG3209/Lab Assignment 2/Assignment 2 Data/Assignment 2 Data/elev.tif"

# %%
elev_df = '/arcgis/home/elev.tif'

# %%
import rasterio
import numpy as np
# %matplotlib inline

# %%
#Task 1
raster = rasterio.open(elev_df)

# %%
#Task 2
print(raster.crs)
# Out:
# EPSG:32617

# %% [markdown]
# #### The raster's CRS is EPSG: 32617

# %%
#Task 3
print(raster.bounds)
print(raster.crs)
print(raster.count)
# Out:
# BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138)
# EPSG:32617
# 1

# %% [markdown]
# #### The raster's bounds are left: 479753.39945587853, bottom: 4170823.2037591375, right: 668843.3994558785, top: 4347733.203759138. The raster's reference system is EPSG: 32617, and the raster has 1 band.

# %%
#Task 4
from rasterio.plot import show
show((raster, 1))
# Out:
# <AxesSubplot: >

# %%
#Task 5
from rasterio.plot import show_hist
show_hist(raster, bins = 50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', 
            title="Histogram")

# %% [markdown]
# ### Part 6

# %% [markdown]
# ### I'm sorry
#
# #### I know I did really poorly in this assignment, and you are probably quite dissapointed in my work. I was sick for a large part of this unit, and I thought I would be able to catch up okay on my own. I got quite behind, and I was too anxious/embarrased to ask for help. I'm not trying to make any excuses because I know it was my responsibilty to stay on top of my work, just trying to provide an explanation. I'm sorry.
